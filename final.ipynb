# %%
import ssl
import pandas as pd
import numpy as np

ssl._create_default_https_context = ssl._create_unverified_context

pd.set_option('display.max_columns', None)

census = pd.read_csv("https://data.wprdc.org/dataset/40188e1c-6d2e-4f20-9391-607bd3054949/resource/8ac5c768-09ba-43a8-829f-ce4a417d20fb/download/population-density.csv",
                           index_col="Neighborhood", 
                           parse_dates=True)

playground = pd.read_csv("https://data.wprdc.org/datastore/dump/e39ef76e-0a11-47c8-a86f-a37f55db7a2b",
                           index_col="neighborhood", 
                           parse_dates=True)

pools = pd.read_csv("https://data.wprdc.org/datastore/dump/5cc254fe-2cbd-4912-9f44-2f95f0beea9a",
                           index_col="neighborhood", 
                           parse_dates=True)
rinks = pd.read_csv("https://data.wprdc.org/datastore/dump/a5b71bfa-840c-4c86-8f43-07a9ae854227",
                           index_col="neighborhood", 
                           parse_dates=True)



print(census.head())
print(playground.head())
print(pools.head())
print(rinks.head())
# Out:
#                    Sector # Pop. 1940 Pop. 1950 Pop. 1960 Pop. 1970 Pop. 1980  \
# Neighborhood
# Allegheny Center          3     4,521     3,862     2,512       632     1,586
# Allegheny West            3     3,210     3,313     2,170     1,124       820
# Allentown                 6     8,227     7,487     6,416     5,361     4,292
# Arlington                 7     2,702     3,203     4,430     3,949     2,294
# Arlington Heights         7     2,413     2,860     2,272     2,037     1,466
#
#                   Pop. 1990 Pop. 2000 Pop. 2010 % Pop. Change, 60-70  \
# Neighborhood
# Allegheny Center      1,262       886       933              -74.84%
# Allegheny West          654       508       462              -48.20%
# Allentown             3,600     3,220     2,500              -16.44%
# Arlington             2,210     1,999     1,869              -10.86%
# Arlington Heights     1,497       238       244              -10.34%
#
#                   % Pop. Change, 70-80 % Pop. Change, 80-90  \
# Neighborhood
# Allegheny Center               150.95%              -20.43%
# Allegheny West                 -27.05%              -20.24%
# Allentown                      -19.94%              -16.12%
# Arlington                      -41.91%               -3.66%
# Arlington Heights              -28.03%                2.11%
#
#                   % Pop. Change, 90-00 % Pop. Change, 00-10  \
# Neighborhood
# Allegheny Center               -29.79%                5.30%
# Allegheny West                 -22.32%               -9.06%
# Allentown                      -10.56%              -22.36%
# Arlington                       -9.55%               -6.50%
# Arlington Heights              -84.10%                2.52%
#
#                   Pop. as % of City total (2010)  Land Area (sq. mi)  \
# Neighborhood
# Allegheny Center                           0.31%                 0.2
# Allegheny West                             0.15%                 0.1
# Allentown                                  0.82%                 0.3
# Arlington                                  0.61%                 0.5
# Arlington Heights                          0.08%                 0.1
#
#                   Land Area (acres) Persons / sq. mi (2010)  \
# Neighborhood
# Allegheny Center              134.4                 4,442.9
# Allegheny West                 90.2                 3,276.6
# Allentown                     188.8                 8,474.6
# Arlington                     300.8                 3,976.6
# Arlington Heights              84.5                 1,848.5
#
#                   Persons / sq. mi (2000)  Persons / acre (2010)  \
# Neighborhood
# Allegheny Center                  4,219.0                    6.9
# Allegheny West                    3,602.8                    5.1
# Allentown                        10,915.3                   13.2
# Arlington                         4,253.2                    6.2
# Arlington Heights                 1,803.0                    2.9
#
#                    Persons / acre (2000) % African American (2010)  \
# Neighborhood
# Allegheny Center                     6.6                    48.55%
# Allegheny West                       5.6                    18.18%
# Allentown                           17.1                    35.12%
# Arlington                            6.6                    19.85%
# Arlington Heights                    2.8                    84.02%
#
#                   % Asian (2010) % Other (2010) % White (2010)  \
# Neighborhood
# Allegheny Center           6.00%          0.64%         40.84%
# Allegheny West             1.52%          0.65%         76.62%
# Allentown                  0.04%          0.80%         59.40%
# Arlington                  0.16%          0.37%         76.46%
# Arlington Heights          0.00%          1.64%          9.43%
#
#                    % 2+ Races (2010)  % Hispanic (of any race) (2010)  \
# Neighborhood
# Allegheny Center              0.0397                            0.029
# Allegheny West                0.0303                            0.028
# Allentown                     0.0464                            0.023
# Arlington                     0.0316                            0.014
# Arlington Heights             0.0492                            0.008
#
#                    % Pop. Age < 5 (2010)  % Pop. Age 5-19 (2010)  \
# Neighborhood
# Allegheny Center                  0.0419                  0.2170
# Allegheny West                    0.0000                  0.0000
# Allentown                         0.0366                  0.1485
# Arlington                         0.0691                  0.1889
# Arlington Heights                 0.0410                  0.3925
#
#                    % Pop. Age 20-34 (2010)  % Pop. Age 35-59 (2010)  \
# Neighborhood
# Allegheny Center                    0.2757                   0.2243
# Allegheny West                      0.0837                   0.6820
# Allentown                           0.2411                   0.3530
# Arlington                           0.1945                   0.3153
# Arlington Heights                   0.1638                   0.3072
#
#                    % Pop. Age 60-74 (2010)  % Pop. Age > 75 (2010)
# Neighborhood
# Allegheny Center                    0.1761                  0.0650
# Allegheny West                      0.1255                  0.1088
# Allentown                           0.1440                  0.0767
# Arlington                           0.0888                  0.1433
# Arlington Heights                   0.0341                  0.0614
#                              id                          name  \
# neighborhood
# Beechview            1780722587          Able Long Playground
# Allegheny Center      702514290         North Ave. Playground
# Squirrel Hill South  1267038491  Vietnam Veteran's Playground
# Squirrel Hill South    14898932  Schenley Overlook Playground
# Squirrel Hill South   204832406  Schenley Overlook Playground
#
#                        equipment_type  manufacturer safety_surface_type  \
# neighborhood
# Beechview            Play Area 2 to 5  Little Tykes       Pour in Place
# Allegheny Center     Play Area 2 to 5     Playworld         SofSurfaces
# Squirrel Hill South             Slide  Little Tykes         SofSurfaces
# Squirrel Hill South      Swing 2 Bays  Little Tykes         SofSurfaces
# Squirrel Hill South             Slide  Little Tykes         SofSurfaces
#
#                     ada_accessible  street_number             street  \
# neighborhood
# Beechview                        f          211.0          Coast Ave
# Allegheny Center                 f          377.0        W North Ave
# Squirrel Hill South              f          108.0  Panther Hollow Rd
# Squirrel Hill South              t            NaN        Overlook Dr
# Squirrel Hill South              f            NaN        Overlook Dr
#
#                      council_district  ward        tract  \
# neighborhood
# Beechview                           4    19  42003192000
# Allegheny Center                    1    22  42003562700
# Squirrel Hill South                 5    14  42003980500
# Squirrel Hill South                 5    14  42003980500
# Squirrel Hill South                 5    14  42003980500
#
#                      public_works_division  pli_division  police_zone  \
# neighborhood
# Beechview                                5            19            6
# Allegheny Center                         1            22            1
# Squirrel Hill South                      3            14            4
# Squirrel Hill South                      3            14            4
# Squirrel Hill South                      3            14            4
#
#                     fire_zone   latitude  longitude
# neighborhood
# Beechview                4-28  40.408381 -80.028520
# Allegheny Center          1-7  40.454526 -80.010188
# Squirrel Hill South       2-8  40.434185 -79.944323
# Squirrel Hill South       2-8  40.432130 -79.947774
# Squirrel Hill South       2-8  40.432215 -79.947817
#                            id                  name        type  retired  \
# neighborhood
# Bedford Dwellings   899591542                 Ammon        Pool      NaN
# Banksville         1003800828            Banksville        Pool      NaN
# Beechview          1688544652  Beechview Spray Park  Spray Park      NaN
# Bloomfield         1533382756            Bloomfield        Pool      NaN
# Hazelwood          1287441950    Burgwin Spray Park  Spray Park      NaN
#
#                                            water_source  capacity  \
# neighborhood
# Bedford Dwellings  Pittsburgh Water and Sewer Authority  538000.0
# Banksville                  Pennsylvania American Water  166320.0
# Beechview                   Pennsylvania American Water       NaN
# Bloomfield         Pittsburgh Water and Sewer Authority  335000.0
# Hazelwood          Pittsburgh Water and Sewer Authority       NaN
#
#                                                                image  \
# neighborhood
# Bedford Dwellings  https://tools.wprdc.org/images/pittsburgh/pool...
# Banksville         https://tools.wprdc.org/images/pittsburgh/pool...
# Beechview          https://tools.wprdc.org/images/pittsburgh/pool...
# Bloomfield         https://tools.wprdc.org/images/pittsburgh/pool...
# Hazelwood          https://tools.wprdc.org/images/pittsburgh/pool...
#
#                    council_district  ward        tract  public_works_division  \
# neighborhood
# Bedford Dwellings                 6     5  42003050900                      3
# Banksville                        2    20  42003202300                      5
# Beechview                         4    19  42003191600                      5
# Bloomfield                        7     8  42003080200                      2
# Hazelwood                         5    15  42003562300                      3
#
#                    pli_division  police_zone fire_zone   latitude  longitude
# neighborhood
# Bedford Dwellings             5            2       2-5  40.448720 -79.978325
# Banksville                   20            6       4-9  40.414758 -80.040551
# Beechview                    19            6      4-28  40.414989 -80.019170
# Bloomfield                    8            5       3-1  40.461989 -79.953310
# Hazelwood                    15            4      2-13  40.405065 -79.936896
#                           id                                   name  \
# neighborhood
# Allegheny Center  1592343416   Allegheny Commons Basketball Court 1
# Allegheny Center  1365248699  Allegheny Commons Park Tennis Court 1
# Allegheny Center  1757180821  Allegheny Commons Park Tennis Court 2
# Allegheny Center   744303307  Allegheny Commons Park Tennis Court 3
# Beechview         1157777481          Alton Park Basketball Court 1
#
#                                type               park location  \
# neighborhood
# Allegheny Center  Basketball (Full)  Allegheny Commons      NaN
# Allegheny Center             Tennis  Allegheny Commons      NaN
# Allegheny Center             Tennis  Allegheny Commons      NaN
# Allegheny Center             Tennis  Allegheny Commons      NaN
# Beechview         Basketball (Half)         Alton Park      NaN
#
#                  surface_material  grandstand inactive  council_district  \
# neighborhood
# Allegheny Center              NaN           0        f                 1
# Allegheny Center          Asphalt           0        f                 1
# Allegheny Center          Asphalt           0        f                 1
# Allegheny Center          Asphalt           0        f                 1
# Beechview                 Asphalt           0        f                 4
#
#                   ward        tract  public_works_division  pli_division  \
# neighborhood
# Allegheny Center    22  42003562700                      1            22
# Allegheny Center    22  42003562700                      1            22
# Allegheny Center    22  42003562700                      1            22
# Allegheny Center    22  42003562700                      1            22
# Beechview           19  42003191600                      5            19
#
#                   police_zone fire_zone   latitude  longitude
# neighborhood
# Allegheny Center            1       1-7  40.454443 -80.008104
# Allegheny Center            1       1-7  40.452400 -80.012531
# Allegheny Center            1       1-7  40.452238 -80.012150
# Allegheny Center            1       1-7  40.452075 -80.011767
# Beechview                   6      4-28  40.414152 -80.022305
